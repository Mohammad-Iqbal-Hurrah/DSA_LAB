# %%
#1.Install Anaconda and launch jupyter notebook.
#2. Explore system packages(Numpy,Pandas,Scikit learn).
#3. Write a simple program to display system info(Python version, packages installed.
import numpy
import pandas
import sklearn
import os
print("Numpy version: ",numpy.__version__)
print("Pandas Version: ",pandas.__version__)
print("Sikit Learn Version: ",sklearn.__version__)
print("File Location: ",os.getcwd()) # to get the file location
# Out:
# Numpy version:  2.1.3
# Pandas Version:  2.2.3
# Sikit Learn Version:  1.6.1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       8 print("Pandas Version: ",pandas.__version__)
#       9 print("Sikit Learn Version: ",sklearn.__version__)
# ---> 10 print("File Location: ",os.getcwd())
#
# NameError: name 'os' is not defined

# %%
import sys, platform
print("Python version: ",sys.version)
print("Plateform: ", platform.system(),platform.release())
# Out:
# Python version:  3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]
# Plateform:  Windows 10

# %%
import os
print(os.getcwd()) # to get the file location
# Out:
# C:\Users\Hp
